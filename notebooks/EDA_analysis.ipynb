# %%
import os
import pandas as pd

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
print(os.getcwd())
os.chdir('C:/Users/hp/Desktop/tutorial/kaim-week-4')
# Out:
# C:\Users\hp\Desktop\tutorial\kaim-week-4

# %%
from scripts.eda import extract_data
path='C:/Users/hp/Desktop/tutorial/kaim-week-4/data/cleaned_train_data.csv'
path_2='C:/Users/hp/Desktop/tutorial/kaim-week-4/data/cleaned_test_data.csv'
path_3='C:/Users/hp/Desktop/tutorial/kaim-week-4/data/cleaned_store_data.csv'
#df=pd.read_csv(path)
train_df=extract_data(path)
test_df=extract_data(path_2)
store_df=extract_data(path_3)
# Out:
# C:\Users\hp\Desktop\tutorial\kaim-week-4\scripts\eda.py:6: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   csv_data=pd.read_csv(data)

# %%
train_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday'],
#       dtype='object')

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             41088 non-null  int64
#  1   Store          41088 non-null  int64
#  2   DayOfWeek      41088 non-null  int64
#  3   Date           41088 non-null  object
#  4   Open           41088 non-null  float64
#  5   Promo          41088 non-null  int64
#  6   StateHoliday   41088 non-null  object
#  7   SchoolHoliday  41088 non-null  int64
# dtypes: float64(1), int64(5), object(2)
# memory usage: 2.5+ MB

# %%
store_df.head()[['CompetitionOpenSinceMonth','CompetitionOpenSinceYear','Promo2SinceWeek','Promo2SinceYear','PromoInterval']]
# Out:
#    CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2SinceWeek  \
# 0                        9.0                    2008.0        23.595447
# 1                       11.0                    2007.0        23.595447
# 2                       12.0                    2006.0        23.595447
# 3                        9.0                    2009.0        23.595447
# 4                        4.0                    2015.0        23.595447
#
#    Promo2SinceYear    PromoInterval
# 0      2011.763573  Jan,Apr,Jul,Oct
# 1      2011.763573  Jan,Apr,Jul,Oct
# 2      2011.763573  Jan,Apr,Jul,Oct
# 3      2011.763573  Jan,Apr,Jul,Oct
# 4      2011.763573  Jan,Apr,Jul,Oct

# %% [markdown]
# Replacing outliers

# %%
#from scripts.eda import outliers
##remove_outliers_train = outliers(train_df)
#remove_outliers_store = outliers(store_df)

# %%
#remove_outliers.to_csv('cleaned_test_data.csv',index=False)
#remove_outliers_store.to_csv('cleaned_store_data.csv',index=False)
#remove_outliers_train.to_csv('cleaned_train_data.csv',index=False)

# %% [markdown]
# Inspect the of promotion in test and train sets
